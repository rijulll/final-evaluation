# %% [markdown]
# <a href="https://colab.research.google.com/github/rijulll/final-evaluation/blob/main/FINAL_EVAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    'house':['Avalon','Cross winds','The white house','The Rectory','Larchwood','orchard house'],
    'sale prize':['2050','2080','2150','2150','1999','1900'],
    'size':['2650','2600','2554','2921','2580','2580'],
    'age':['13','*','6','3','4','4']
}
df=pd.DataFrame(data)
df.to_csv('house.csv',index=False)
print(df)
# Out:
#              house sale prize  size age
# 0           Avalon       2050  2650  13
# 1      Cross winds       2080  2600   *
# 2  The white house       2150  2554   6
# 3      The Rectory       2150  2921   3
# 4        Larchwood       1999  2580   4
# 5    orchard house       1900  2580   4

# %%
import pandas as pd
data={
    'house':['Avalon','Cross winds','The white house','The Rectory','Larchwood','orchard house'],
    'sale prize':['2050','2080','2150','2150','1999','1900'],
    'size':['2650','2600','2554','2921','2580','2580'],
    'age':['13','*','6','3','4','4']
}
df=pd.DataFrame(data)
print(df)
df.iloc[:,1:3]  #iloc is used to isolate the desired columns
# Out:
#              house sale prize  size age
# 0           Avalon       2050  2650  13
# 1      Cross winds       2080  2600   *
# 2  The white house       2150  2554   6
# 3      The Rectory       2150  2921   3
# 4        Larchwood       1999  2580   4
# 5    orchard house       1900  2580   4
#   sale prize  size
# 0       2050  2650
# 1       2080  2600
# 2       2150  2554
# 3       2150  2921
# 4       1999  2580
# 5       1900  2580
